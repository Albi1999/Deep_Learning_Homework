# %% [markdown]
# # **Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti & Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Finally, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder).

# %% [markdown]
# #Requirements

# %%
# !pip3 install datasets skorch pandas torch torchinfo torchdata torchtext torchvision torchaudio
# Out:
# Requirement already satisfied: datasets in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (2.19.1)
# Requirement already satisfied: skorch in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (0.15.0)
# Requirement already satisfied: pandas in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: torch in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: torchinfo in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: torchdata in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (0.7.1)
# Requirement already satisfied: torchtext in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: torchvision in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from datasets) (6.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from skorch) (1.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from skorch) (1.10.1)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from skorch) (0.8.10)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: urllib3>=1.25 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torchdata) (1.26.16)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/albertocalabrese99/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# #Imports

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torchinfo import summary
from torchvision.datasets import CIFAR10
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from timeit import default_timer as timer
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Loading
#
# We load the `CIFAR-10 dataset`, available from `torchvision.datasets`. This dataset is one of the most popular benckmark in the filed of Computer Vision. It consits of $10$ different classes, that represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. The dataset contains $50,000$ training images and $10,000$ images for testing.
#
# First, we will pre-process them with a `PreProcessing` fuction that works in the following way. The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between $0$ and $255$, and it represents a point of an image of size $32\times32$. We will normalize all values between $0$ and $1$, and we will flatten the $32\times32$ images into vectors of size $1024$.
# Moreover, since no validation set is defined, we split the train set in a validation set and a new test set.
# Finally, we design a custom dataset class, derived from the standard `Dataset` class, that returns a PyTorch Dataset object, along with its noisy version. The Gaussian noise is tunable with the `noise_factor` parameter and will be used for the Denoising Autoencoder.

# %%
to_tensor = transforms.ToTensor()

def PreProcessing(img):
  img = to_tensor(img) #PIL to tensor + Scaling
  img = torch.mean(img, 0) #One channel averaged over the colors
  img = img.reshape(torch.prod(torch.tensor(img.shape))) #Flattening
  return img.to(torch.float32)

# %%
dataset = CIFAR10(root='data/', download=True, train=True, transform=transforms.Lambda(PreProcessing)) # 50000 samples
test_data = CIFAR10(root='data/', download=True, train=False, transform=transforms.Lambda(PreProcessing)) # 10000 samples
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
val_size = 10000
train_size = len(dataset) - val_size

train_data, val_data = random_split(dataset, [train_size, val_size])
print(f"Training samples = {len(train_data)} \nValidation samples = {len(val_data)} \nTest samples = {len(test_data)}")
# Out:
# Training samples = 40000
# Validation samples = 10000
# Test samples = 10000

# %%
class CustomDataset(Dataset):
  def __init__(self, dataset, noise_factor, device='cpu'):
    super().__init__()
    self.dataset = dataset
    self.nf = noise_factor
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    x, _ = self.dataset[idx]
    x_noisy = x + self.nf*np.random.normal(loc=0.0, scale=1.0, size=x.shape)
    x_noisy = np.clip(x_noisy, 0., 1.).to(torch.float32)
    return (x.to(device), x_noisy.to(device))

# %% [markdown]
# # Q1 [TO COMPLETE] SVD
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linearly combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices, $V$ and $U$, and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in PyTorch as `torch.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def svd_k(X, k):
  # k: sets the number of components to keep

  # Compute the matrix C
  C = torch.matmul(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = torch.linalg.svd(C)
  # Limit the number columns of U to k
  U_k = U[:,:k]
  return U_k

# %% [markdown]
# Now we create the dataset ready for the SVD:

# %%
device = torch.device("cpu") # for SVD
noise_factor = 0.1

x_train, x_train_noisy = next(iter(DataLoader(CustomDataset(train_data, noise_factor, device), batch_size=len(train_data))))
x_val, x_val_noisy = next(iter(DataLoader(CustomDataset(val_data, noise_factor, device), batch_size=len(val_data))))
x_test, x_test_noisy = next(iter(DataLoader(CustomDataset(test_data, noise_factor, device), batch_size=len(test_data))))

x_train.shape, x_train_noisy.shape, x_val.shape, x_val_noisy.shape, x_test.shape, x_test_noisy.shape
# Out:
# (torch.Size([40000, 1024]),
#  torch.Size([40000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]))

# %% [markdown]
# Let's define the ENCODING_DIM, that will be the size of the compressed version of input data. And compute the compressed version of the training set and test set.

# %%
def SVD_Rec(emb_dim, out_test_reco=False):
    U_k = svd_k(x_train, emb_dim)
    x_training_svd = torch.matmul(x_train, U_k)
    x_test_svd = torch.matmul(x_test, U_k)
    x_training_reco = torch.matmul(x_training_svd, U_k.T)
    x_test_reco = torch.matmul(x_test_svd, U_k.T)
    accuracy_train = ((x_train - x_training_reco)**2).mean()
    accuracy_test = ((x_test - x_test_reco)**2).mean()
    if not out_test_reco:
      return accuracy_train, accuracy_test
    else:
      return accuracy_train, accuracy_test, x_test_reco

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
ENCODING_DIM = 256 # [TO COMPLETE]
accuracy_train, accuracy_test = SVD_Rec(ENCODING_DIM)
print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00150
# Test mse: 0.00153

# %%
train_accuracies = {}
test_accuracies = {}

for emb_dim in [64, 128, 256, 384]:
    accuracy_train, accuracy_test = SVD_Rec(emb_dim)
    train_accuracies[emb_dim] = accuracy_train
    test_accuracies[emb_dim] = accuracy_test

# %%
plt.plot(train_accuracies.keys(), train_accuracies.values(), marker='*', label='train')
plt.plot(test_accuracies.keys(), test_accuracies.values(), marker='o', label='test')
plt.grid()
plt.xlabel("Embedding dimension")
plt.ylabel('MSE')
plt.legend(loc='best')
plt.show()

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
emb_dim = 256 # [TO COMPLETE]
train_acc, test_acc, x_test_reco = SVD_Rec(emb_dim, True)
print("Training mse: %.5f" % ( train_acc))
print("Test mse: %.5f" % ( test_acc))
_ = plot_img(10, [x_test, x_test_reco], title="Original (top) vs reconstruction (bottom)")
# Out:
# Training mse: 0.00150
# Test mse: 0.00153

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the ENCODING_DIM?
#  Test and discuss the results in a cell below with reference to plot shown above.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# I tried to variate the variable ENCODING_DIM as follow:
#
# |ENCODING_DIM|Training MSE|Test MSE|
# |-|-|-|
# |ENCODING_DIM = 64|Training mse: 0.00628|Test mse: 0.00631|
# |ENCODING_DIM = 128|Training mse: 0.00349|Test mse: 0.00353|
# |ENCODING_DIM = 256|Training mse: 0.00150|Test mse: 0.00153|
# |ENCODING_DIM = 384|Training mse: 0.00073|Test mse: 0.00076|
# |ENCODING_DIM = 512|Training mse: 0.00037|Test mse: 0.00039|
#
#
# An increase in the ENCODING_DIM variable results in an observable improvement in image reconstruction. This improvement can be attributed to the fact that as the encoding dimension approaches the sample dimension, the loss of information decreases. Conversely, if we move away from the sample dimension, the amount of lost information increases, resulting in worse image reconstruction.
#
# Based on these observations, it was decided to keep the ENCODING_DIM set to 256.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Q2 [TO COMPLETE] Shallow Linear Autoencoder

# %% [markdown]
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. First, we define the `DataLoader` to train the model.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 512
noise_factor = 0.1 # adjust the noise level here.

dataloader_train_AE = DataLoader(CustomDataset(train_data, noise_factor, device), batch_size = batch_size)
dataloader_val_AE = DataLoader(CustomDataset(val_data, noise_factor, device), batch_size = batch_size)
dataloader_test_AE = DataLoader(CustomDataset(test_data, noise_factor, device), batch_size = batch_size)

# %% [markdown]
# Then, we build our shallow Autoencoder. Here's a breakdown of the code to help you grasp how it works:
#
# 1. The `__init__` method is the initialization function for the Auto_Encoder class. It takes four parameters: `input_dim` (dimensionality of the input data), `enc_layers` (a list specifying the sizes of the encoder layers), `dec_layers` (a list specifying the sizes of the decoder layers), and `act_fun` (the activation function to be used).
#
# 2. The `nn.ModuleList()` is used to create empty lists E_layers and D_layers to store the encoder and decoder layers, respectively.
#
# 3. The `for loop `iterates over the `enc_layers` list to create the encoder layers. For the first layer, it creates a linear layer (`nn.Linear`) mapping from the input dimension to the size of the first encoder layer. For subsequent layers, it creates linear layers mapping between consecutive encoder layer sizes. The created layers are appended to the `self.E_layers` list.
#
# 4. The code then checks if the `dec_layers` list is empty. If it is empty, it creates a single linear layer mapping from the last encoder layer size to the input dimension (remember: the goal of the AE is to reconstruct the input). Otherwise, it iterates over the `dec_layers` list to create the decoder layers, similar to how the encoder layers were created. The last decoder layer is always mapped to the input dimension.
#
# 5. The `_init_weights` method is a helper function that initializes the weights of the linear layers. It is applied to all modules (layers) of the Auto_Encoder instance.
#
# 6. **[TO COMPLETE]** The `forward` method defines the forward pass of the Autoencoder. Your task is to complete the forward function and choose the appropriate activation function.

# %% [markdown]
# `%STARTCODE`

# %%
class Auto_Encoder(nn.Module):

  def __init__(self, input_dim, enc_layers, dec_layers, act_fun):
    super().__init__()

    self.E_layers = nn.ModuleList()
    self.D_layers = nn.ModuleList()
    self.act_fun = act_fun
    activation_functions = {'linear': transforms.Lambda(lambda x: x),
                            'sigmoid': F.sigmoid,
                            'relu': F.relu,
                            'tanh': F.tanh,
                            'leaky_relu': F.leaky_relu}

    assert self.act_fun in activation_functions, f'Activation Functions: {activation_functions.keys()}'
    self.af = activation_functions[self.act_fun]

    for layer_idx in range(len(enc_layers)):
      if layer_idx == 0:  # first layer, from input to enc
        self.E_layers = self.E_layers.append(nn.Linear(input_dim, enc_layers[layer_idx]))
      else:  # hidden layers, depending on the input
        self.E_layers = self.E_layers.append(nn.Linear(enc_layers[layer_idx-1], enc_layers[layer_idx]))

    if len(dec_layers) == 0:
      self.D_layers = self.D_layers.append(nn.Linear(enc_layers[-1], input_dim))
    else:
      for layer_idx in range(len(dec_layers)):
        if layer_idx == 0:  # first layer, from enc to dec
          self.D_layers = self.D_layers.append(nn.Linear(enc_layers[-1], dec_layers[layer_idx]))
        else:  # hidden layers, depending on the input
          self.D_layers = self.D_layers.append(nn.Linear(dec_layers[layer_idx-1], dec_layers[layer_idx]))

      self.D_layers = self.D_layers.append(nn.Linear(dec_layers[-1], input_dim)) # final output layer

    self.apply(self._init_weights)

  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()

  def forward(self, x):
    for layer in self.E_layers:
        x = self.af(layer(x)) #[TO COMPLETE]
    for layer in self.D_layers[:-1]:
        x = self.af(layer(x)) #[TO COMPLETE]
    if self.act_fun == 'linear': #[TO COMPLETE]
        return self.D_layers[-1](x)
    else:
      return F.sigmoid(self.D_layers[-1](x)) #last act func is always sigmoid

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# **[TO COMPLETE]** check the results and compare them with the ones obtained with the SVD. In the cell at the end of this section (after the result of the linear autoencoder), give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
# Try also to be aquainted with the usual PyTorch training and evaluation routines. In the following part of the HW, the more training epochs the better the resutls, but it will also take longer. Feel free to change the `epochs` variable, just be consistent to make fair comparisons.

# %%
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256]
DEC_LAYERS = []
ACT_FUN = 'linear'
lr = 0.005
epochs = 15 # Feel free to adjust this to speed up the training times. Nevertheless, esure the model is training long enough

Shallow_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(Shallow_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 256]                262,400
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-2                       [512, 1024]               263,168
# ==========================================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 269.09
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 5.24
# Params size (MB): 2.10
# Estimated Total Size (MB): 9.44
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(Shallow_AE.parameters(), lr=lr)

# %%
def train(model, optimizer, dataloader_train, dataloader_val, epochs, print_step=1, tunning=False, denoising=False):
  loss_train, loss_val = [], []
  for epoch in range(epochs):

    model.train()
    total_count_train, n_train_batches, total_loss_train = 0, 0, 0
    for idx, (x, x_noisy) in enumerate(dataloader_train):
      optimizer.zero_grad()
      if denoising:
        x_rec = model(x_noisy)
      else:
        x_rec = model(x)
      loss = criterion(x_rec, x)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_count_train += x.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())

    total_count_val, n_val_batches, total_loss_val = 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (x, x_noisy) in enumerate(dataloader_val):
            if denoising:
              x_rec = model(x_noisy)
            else:
              x_rec = model(x)

            loss = criterion(x_rec, x)
            total_loss_val += loss
            total_count_val += x.size(0)
            n_val_batches += 1

    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    if epoch % print_step == 0 and not tunning:
      print(f"epoch: {epoch+1} -> Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: Val_Loss: {avg_loss_val:.8f}")
  return loss_train, loss_val

# %%
start = timer()
loss_train, loss_val = train(Shallow_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.84399897 ---------------- Val_Acc: Val_Loss: 0.24248056
# epoch: 2 -> Loss: 0.18567996 ---------------- Val_Acc: Val_Loss: 0.14371081
# epoch: 3 -> Loss: 0.13396527 ---------------- Val_Acc: Val_Loss: 0.09873728
# epoch: 4 -> Loss: 0.08442482 ---------------- Val_Acc: Val_Loss: 0.07304645
# epoch: 5 -> Loss: 0.06428840 ---------------- Val_Acc: Val_Loss: 0.05739681
# epoch: 6 -> Loss: 0.05116587 ---------------- Val_Acc: Val_Loss: 0.04680252
# epoch: 7 -> Loss: 0.04207786 ---------------- Val_Acc: Val_Loss: 0.03864875
# epoch: 8 -> Loss: 0.03525662 ---------------- Val_Acc: Val_Loss: 0.03291684
# epoch: 9 -> Loss: 0.03017707 ---------------- Val_Acc: Val_Loss: 0.02827865
# epoch: 10 -> Loss: 0.02605587 ---------------- Val_Acc: Val_Loss: 0.02467259
# epoch: 11 -> Loss: 0.02296774 ---------------- Val_Acc: Val_Loss: 0.02201562
# epoch: 12 -> Loss: 0.02062009 ---------------- Val_Acc: Val_Loss: 0.01971396
# epoch: 13 -> Loss: 0.01829009 ---------------- Val_Acc: Val_Loss: 0.01773628
# epoch: 14 -> Loss: 0.01656872 ---------------- Val_Acc: Val_Loss: 0.01622041
# epoch: 15 -> Loss: 0.01516166 ---------------- Val_Acc: Val_Loss: 0.01479208
# Training time in second: 415.927891607

# %%
def plot_learning_acc_and_loss(loss_tr, loss_val):
    info = {'loss_training':loss_tr, 'loss_validation':loss_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(10, 8), subplots=[('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
def test(model, dataloader_test=dataloader_test_AE, tunning=False, denoising=False): #dataloader_test_AE not train
  model.eval()
  total_count_test, n_batches_test, loss = 0, 0, 0
  for idx, (x, x_noisy) in enumerate(dataloader_test):
      if denoising:
        x_rec = model(x_noisy)
      else:
        x_rec = model(x)
      loss += criterion(x_rec, x)
      total_count_test += x.size(0)
      n_batches_test += 1
  loss_test = loss/n_batches_test
  if not tunning:
    print(f"Test Loss: {loss_test:.8f}")
  else:
    return loss_test

# %%
test(Shallow_AE)
# Out:
# Test Loss: 0.01487728

# %%
train_mse = {}
test_mse = {}
epochs = 15 # just to test
for emb_dim in [16, 32, 64, 128, 256]:
    ENC_LAYERS = [emb_dim]
    Shallow_AE_Cand = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
    optimizer = torch.optim.Adam(Shallow_AE_Cand.parameters(), lr=lr)
    loss_train, _ = train(Shallow_AE_Cand, optimizer, dataloader_train_AE,
                          dataloader_val_AE, epochs, tunning=True)

    train_mse[emb_dim] = loss_train[-1]
    test_mse[emb_dim] = test(Shallow_AE_Cand, tunning=True).item()

# %%
plt.plot(train_mse.keys(), train_mse.values(), marker='*', label='train')
plt.plot(test_mse.keys(), test_mse.values(), marker='o', label='test')
plt.grid()
plt.xlabel("Encoder layer dimension")
plt.ylabel('MSE')
plt.legend(loc='best')
plt.show()

# %%
BEST_ENC_LAYERS = [256] # should be changed to the best one.
epochs = 30 # try with higher number than before
BEST_Shallow_AE = Auto_Encoder(IN_DIM, BEST_ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
# epoch: 27 -> Loss: 0.00742756 ---------------- Val_Acc: Val_Loss: 0.00744935
# epoch: 28 -> Loss: 0.00714151 ---------------- Val_Acc: Val_Loss: 0.00966101
# epoch: 29 -> Loss: 0.00718177 ---------------- Val_Acc: Val_Loss: 0.00726222
# epoch: 30 -> Loss: 0.00667535 ---------------- Val_Acc: Val_Loss: 0.00669153

# %%
@torch.no_grad()
def apply_on_test(model, device, denoising=False):
  if denoising:
    x = x_test_noisy.to(device)
  else:
    x = x_test.to(device)
  for layer in model.E_layers:
      x = model.af(layer(x))
  encoded_imgs = x


  y = encoded_imgs
  for layer in model.D_layers[:-1]:
      y = model.af(layer(y))
  if model.act_fun == 'linear':
    decoded_imgs = model.D_layers[-1](y)
  else:
    decoded_imgs = F.sigmoid(model.D_layers[-1](y))

  return (encoded_imgs.to("cpu"), decoded_imgs.to("cpu"))

# %%
# encoded_imgs, decoded_imgs = apply_on_test(model=Shallow_AE, device=device)
encoded_imgs, decoded_imgs = apply_on_test(model=BEST_Shallow_AE, device=device)

# %%
plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# Comment the results obtained with the shallow linear autoencoder in relation to the ones obtained by the SVD decomposition. Are they different or similar? Why do you think they are so? (hint: consider the theoretical relationship between SVD and a shallow linear autoencoder.)

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# I compared the results between the the models as follows:
#
# **Shallow Linear AE:**
# ```python
# ENC_LAYERS = [64]
# DEC_LAYERS = []
# ACT_FUN = 'linear'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.00763752
#
# **SVD:**
# ```python
# ENCODING_DIM = 64
# ```
# Test mse: 0.00631
#
# ------------------
#
# **Shallow Linear AE:**
# ```python
# ENC_LAYERS = [128]
# DEC_LAYERS = []
# ACT_FUN = 'linear'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.01220348
#
# **SVD:**
# ```python
# ENCODING_DIM = 128
# ```
# Test mse: 0.00353
#
# ------------------
#
# **Shallow Linear AE:**
# ```python
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'linear'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.00667535
#
# **SVD:**
# ```python
# ENCODING_DIM = 256
# ```
# Test mse: 0.00153
#
# ------------------
#
# **Shallow Linear AE:**
# ```python
# ENC_LAYERS = [512]
# DEC_LAYERS = []
# ACT_FUN = 'linear'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.01790835
#
# **SVD:**
# ```python
# ENCODING_DIM = 512
# ```
# Test mse: 0.00039
#
# ------------------
#
# The results of the shallow linear encoder differ from those of the SVD, as illustrated in the preceding results. It can be observed that the image reconstruction is inferior to that achieved by SVD, which provides the optimal solution for linear transformation.
# In contrast, the encoder employs a numerical solution with an optimization algorithm to identify a local minimum, which may not necessarily be the optimal solution.
#
# In this case, the test loss of the linear encoder with dimension equal to 256 was found to be superior to that of the other encoder with dimension equal to 512. This result contrasts with that observed in the SVD.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# # Q3 [TO COMPLETE] Shallow non-linear Autoencoder

# %% [markdown]
# **[TO COMPLETE]** Replicate the code of the previous exercise but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice in the last cell of this section. Discuss the results you obtained in relation to those obtained with the Shallow Linear Autoencoder.

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256] 
DEC_LAYERS = []
ACT_FUN = 'sigmoid'
lr = 0.005
epochs = 30

Shallow_non_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
# epoch: 25 -> Loss: 0.00792715 ---------------- Val_Acc: Val_Loss: 0.00700827
# epoch: 26 -> Loss: 0.00674857 ---------------- Val_Acc: Val_Loss: 0.00646860
# epoch: 27 -> Loss: 0.00664333 ---------------- Val_Acc: Val_Loss: 0.00630970
# epoch: 28 -> Loss: 0.00662272 ---------------- Val_Acc: Val_Loss: 0.00650117
# epoch: 29 -> Loss: 0.00668146 ---------------- Val_Acc: Val_Loss: 0.00691131
# epoch: 30 -> Loss: 0.00673252 ---------------- Val_Acc: Val_Loss: 0.00635940
# Training time in second: 721.4599161370002

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(Shallow_non_AE)
# Out:
# Test Loss: 0.00637900

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=Shallow_non_AE, device=device)

plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Discuss the results you obtained with the activation functions you have tested and also motivate your choice. Compare your results to the ones obtained with the Shallow Linear Autoencoder.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# I tried to change the activation functions and compared the models as follow:
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'relu'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.02089610
# Training time: 620.2488070460022
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'leaky_relu'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.00923535
# Training time: 632.0903852539996
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'tanh'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.01067567
# Training time: 680.459830775002
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'sigmoid'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.00637900
# Training time: 721.4599161370002
#
# I tried all the different activation functions, and the best one I found was the sigmoid.
#
# Compared to the Shallow Linear Autoencoder, it slightly decreases the test loss and improves image reconstruction.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Q4 [TO COMPLETE] Deep Autoencoder

# %% [markdown]
# **[TO COMPLETE]**: Define a deep version of the Autoeancoder defined above. The autoencoder has to **use at least $5$ layers**. The model will use 𝑛 layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g. `IN_DIM` → $k$ → $k/2$, where $k/2$ is the arbitrarly chosen encoding dim). The decoding part layers dimensions progression turns out to be mirrored (i.e., $k$ → `IN_DIM`, the resulting overall structure recalls an hourglass!). Try different hyperparameters configurations and write a short report of your experiments below. Leave the best execution in the code cells.

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [512, 256, 128] 
DEC_LAYERS = [256, 512]
ACT_FUN = 'leaky_relu'
lr = 0.001
epochs = 50

DEEP_non_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(DEEP_non_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 512]                524,800
# │    └─Linear: 2-2                       [512, 256]                131,328
# │    └─Linear: 2-3                       [512, 128]                32,896
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-4                       [512, 256]                33,024
# │    └─Linear: 2-5                       [512, 512]                131,584
# │    └─Linear: 2-6                       [512, 1024]               525,312
# ==========================================================================================
# Total params: 1,378,944
# Trainable params: 1,378,944
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 706.02
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 11.01
# Params size (MB): 5.52
# Estimated Total Size (MB): 18.62
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(DEEP_non_AE.parameters(), lr=lr)

# %%
start = timer()
loss_train, loss_val = train(DEEP_non_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0
# epoch: 34 -> Loss: 0.01396878 ---------------- Val_Acc: Val_Loss: 0.01392830
# epoch: 35 -> Loss: 0.01390382 ---------------- Val_Acc: Val_Loss: 0.01366336
# epoch: 36 -> Loss: 0.01369257 ---------------- Val_Acc: Val_Loss: 0.01368790
# epoch: 37 -> Loss: 0.01354582 ---------------- Val_Acc: Val_Loss: 0.01344713
# epoch: 38 -> Loss: 0.01343182 ---------------- Val_Acc: Val_Loss: 0.01332468
# epoch: 39 -> Loss: 0.01326479 ---------------- Val_Acc: Val_Loss: 0.01324036
# epoch: 40 -> Loss: 0.01313379 ---------------- Val_Acc: Val_Loss: 0.01327557
# epoch: 41 -> Loss: 0.01308028 ---------------- Val_Acc: Val_Loss: 0.01363801
# epoch: 42 -> Loss: 0.01301634 ---------------- Val_Acc: Val_Loss: 0.01295293
# epoch: 43 -> Loss: 0.01285075 ---------------- Val_Acc: Val_Loss: 0.01277173
# epoch: 44 -> Loss: 0.01276214 ---------------- Val_Acc: Val_Loss: 0.01273154
# epoch: 45 -> Loss: 0.01266023 ---------------- Val_Acc: Val_Loss: 0.01286349
# epoch: 46 -> Loss: 0.01250297 ---------------- Val_Acc: Val_Loss: 0.01257243
# epoch: 47 -> Loss: 0.01251972 ---------------- Val_Acc: Val_Loss: 0.01235890
# epoch: 48 -> Loss: 0.01220981 ---------------- Val_Acc: Val_Loss: 0.01229470
# epoch: 49 -> Loss: 0.01222589 ---------------- Val_Acc: Val_Loss: 0.01214560
# epoch: 50 -> Loss: 0.01201447 ---------------- Val_Acc: Val_Loss: 0.01196646
# Training time in second: 1246.3790889670008

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(DEEP_non_AE)
# Out:
# Test Loss: 0.01208373

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=DEEP_non_AE, device=device)

plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Write a short report of the results you obtained trying different hyperparameters configurations.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# These are the combination of test that I tried:
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'sigmoid'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.03120015
# Training time: 677.5360668430003
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'tanh'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.04139405
# Training time: 676.9889038409965
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'relu'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.01853603
# Training time: 660.7932349859984
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'leaky_relu'
# lr = 0.005
# epochs = 30
# ```
# Test Loss: 0.01763590
# Training time: 660.957788271
#
# The best is the last one, so I decided to keep this activation function and increase the number of epochs as follow:
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'leaky_relu'
# lr = 0.005
# epochs = 50
# ```
# Test Loss: 0.01391276
# Training time: 1192.5282449870065
#
# The Test Loss is decreased but we are far from the results obtained with the Shallow Linear and non-linear Autoencored so I decided to try to reduce the learning rate as follows:
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'leaky_relu'
# lr = 0.001
# epochs = 50
# ```
# Test Loss: 0.01208373
# Training time: 1246.3790889670008
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'leaky_relu'
# lr = 0.0005
# epochs = 50
# ```
# Test Loss: 0.01389085
# Training time: 1183.4411403990016
#
# We have no more decrease so I decided to keep as best model this one:
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'leaky_relu'
# lr = 0.001
# epochs = 50
# ```
# Test Loss: 0.01208373
# Training time: 1246.3790889670008
#
#
# I started by adding more layers and testing them with different activation functions.
# The best one I found used "leaky_relu" as the activation function.
# However, I noticed that increasing the number of layers led to worse outcomes due to information loss.
# To address this, I tried increasing the number of epochs and reducing the learning rate, which resulted in a slightly better test loss, but the image reconstruction remains poor.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Q5 [TO COMPLETE] Shallow Denoising Autoencoder

# %% [markdown]
# **[TO COMPLETE]** Let's now use a shallow autoencoder to denoise the input data. We have defined a Dataloader able to return a noisy version of the input data. You can activate this capability by passing the parameter `denoising=True` to the `train` function.
#
# Run some experiments with different hyperparameters values, and write a short report of your findings below. You can also re-create the dataloaders at the beginning of the notebook and test what happens if you increase the noise level above $0.1$.

# %%
plot_img(10, [x_test, x_test_noisy])

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256]
DEC_LAYERS = []
ACT_FUN = 'sigmoid'
lr = 0.001
epochs = 30

SHALLOW_denoising_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(SHALLOW_denoising_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 256]                262,400
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-2                       [512, 1024]               263,168
# ==========================================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 269.09
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 5.24
# Params size (MB): 2.10
# Estimated Total Size (MB): 9.44
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(SHALLOW_denoising_AE.parameters(), lr=lr)

# %%
start = timer()
loss_train, loss_val = train(SHALLOW_denoising_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs, denoising= True)

end = timer()
print(f"Training time in second: {round(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.04887587 ---------------- Val_Acc: Val_Loss: 0.03643788
# epoch: 2 -> Loss: 0.02945981 ---------------- Val_Acc: Val_Loss: 0.02345144
# epoch: 3 -> Loss: 0.02071312 ---------------- Val_Acc: Val_Loss: 0.01851163
# epoch: 4 -> Loss: 0.01707838 ---------------- Val_Acc: Val_Loss: 0.01597359
# epoch: 5 -> Loss: 0.01503178 ---------------- Val_Acc: Val_Loss: 0.01428750
# epoch: 6 -> Loss: 0.01369927 ---------------- Val_Acc: Val_Loss: 0.01318092
# epoch: 7 -> Loss: 0.01266306 ---------------- Val_Acc: Val_Loss: 0.01228459
# epoch: 8 -> Loss: 0.01189389 ---------------- Val_Acc: Val_Loss: 0.01144485
# epoch: 9 -> Loss: 0.01121899 ---------------- Val_Acc: Val_Loss: 0.01083915
# epoch: 10 -> Loss: 0.01061463 ---------------- Val_Acc: Val_Loss: 0.01048398
# epoch: 11 -> Loss: 0.01015780 ---------------- Val_Acc: Val_Loss: 0.00992377
# epoch: 12 -> Loss: 0.00978961 ---------------- Val_Acc: Val_Loss: 0.00954156
# epoch: 13 -> Loss: 0.00943616 ---------------- Val_Acc: Val_Loss: 0.00921415
# epoch: 14 -> Loss: 0.00912768 ---------------- Val_Acc: Val_Loss: 0.00894999
# epoch: 15 -> Loss: 0.00887221 ---------------- Val_Acc: Val_Loss: 0.00878703
# epoch: 16 -> Loss: 0.00863140 ---------------- Val_Acc: Val_Loss: 0.00845329
# epoch: 17 -> Loss: 0.00840410 ---------------- Val_Acc: Val_Loss: 0.00827020
# epoch: 18 -> Loss: 0.00822672 ---------------- Val_Acc: Val_Loss: 0.00808761
# epoch: 19 -> Loss: 0.00802402 ---------------- Val_Acc: Val_Loss: 0.00791647
# epoch: 20 -> Loss: 0.00787006 ---------------- Val_Acc: Val_Loss: 0.00777789
# epoch: 21 -> Loss: 0.00771292 ---------------- Val_Acc: Val_Loss: 0.00763100
# epoch: 22 -> Loss: 0.00756922 ---------------- Val_Acc: Val_Loss: 0.00757452
# epoch: 23 -> Loss: 0.00749664 ---------------- Val_Acc: Val_Loss: 0.00738879
# epoch: 24 -> Loss: 0.00732586 ---------------- Val_Acc: Val_Loss: 0.00739556
# epoch: 25 -> Loss: 0.00722440 ---------------- Val_Acc: Val_Loss: 0.00729938
# epoch: 26 -> Loss: 0.00714161 ---------------- Val_Acc: Val_Loss: 0.00731413
# epoch: 27 -> Loss: 0.00708511 ---------------- Val_Acc: Val_Loss: 0.00700179
# epoch: 28 -> Loss: 0.00695969 ---------------- Val_Acc: Val_Loss: 0.00697484
# epoch: 29 -> Loss: 0.00690305 ---------------- Val_Acc: Val_Loss: 0.00685362
# epoch: 30 -> Loss: 0.00678071 ---------------- Val_Acc: Val_Loss: 0.00679360
# Training time in second: 746

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(SHALLOW_denoising_AE, denoising=True)
# Out:
# Test Loss: 0.00680821

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=SHALLOW_denoising_AE, device=device, denoising=True)

plot_img(10, [x_test_noisy, x_test, decoded_imgs], title="Noisy, Original vs Reconstruction")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# How strong is the impact of the noise factor on the model's denoising capability? What hyperparameter configuration worked for the noise levels you have tried?

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# **noise_factor = 0.1**
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'sigmoid'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.00680821
# Training time: 746
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'tanh'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.00906303
# Training time: 637
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'relu'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.01056478
# Training time: 600
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'leaky_relu'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.01083308
# Training time: 591
#
# --------------------------------
#
# **noise_factor = 0.5**
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'sigmoid'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.00696477
# Training time: 616
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'tanh'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.00888173
# Training time: 722
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'relu'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.01119250
# Training time: 605
#
# ```python
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'leaky_relu'
# lr = 0.001
# epochs = 30
# ```
# Test Loss: 0.01095982
# Training time: 608
#
# I tried the model with different activation functions and even when we change the noise factor we have minimal differences in terms of Test Loss and image reconstrucion.
# The best model that I found in this exercise is the one with the sigmoid activation function and noise_factor = 0,1.

# %% [markdown]
# `%ENDTEXT`
